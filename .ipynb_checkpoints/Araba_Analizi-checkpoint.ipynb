# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sbn

# %%
dataFrame=pd.read_excel("merc.xlsx")

# %%
dataFrame.head()
# Out:
#    year  price transmission  mileage  tax   mpg  engineSize
# 0  2005   5200    Automatic    63000  325  32.1         1.8
# 1  2017  34948    Automatic    27000   20  61.4         2.1
# 2  2016  49948    Automatic     6200  555  28.0         5.5
# 3  2016  61948    Automatic    16000  325  30.4         4.0
# 4  2016  73948    Automatic     4000  325  30.1         4.0

# %%
dataFrame.describe()
# Out:
#                year          price        mileage           tax           mpg  \
# count  13119.000000   13119.000000   13119.000000  13119.000000  13119.000000
# mean    2017.296288   24698.596920   21949.559037    129.972178     55.155843
# std        2.224709   11842.675542   21176.512267     65.260286     15.220082
# min     1970.000000     650.000000       1.000000      0.000000      1.100000
# 25%     2016.000000   17450.000000    6097.500000    125.000000     45.600000
# 50%     2018.000000   22480.000000   15189.000000    145.000000     56.500000
# 75%     2019.000000   28980.000000   31779.500000    145.000000     64.200000
# max     2020.000000  159999.000000  259000.000000    580.000000    217.300000
#
#          engineSize
# count  13119.000000
# mean       2.071530
# std        0.572426
# min        0.000000
# 25%        1.800000
# 50%        2.000000
# 75%        2.100000
# max        6.200000

# %%
dataFrame.isnull().sum() # nan kolan sayılarını
# Out:
# year            0
# price           0
# transmission    0
# mileage         0
# tax             0
# mpg             0
# engineSize      0
# dtype: int64

# %%
plt.figure(figsize=(7,5))
sbn.distplot(dataFrame["price"])

# %%
sbn.countplot(dataFrame["year"])

# %%
dataFrame.corr()
# Out:
#                 year     price   mileage       tax       mpg  engineSize
# year        1.000000  0.520712 -0.738027  0.012480 -0.094626   -0.142147
# price       0.520712  1.000000 -0.537214  0.268717 -0.438445    0.516126
# mileage    -0.738027 -0.537214  1.000000 -0.160223  0.202850    0.063652
# tax         0.012480  0.268717 -0.160223  1.000000 -0.513742    0.338341
# mpg        -0.094626 -0.438445  0.202850 -0.513742  1.000000   -0.339862
# engineSize -0.142147  0.516126  0.063652  0.338341 -0.339862    1.000000

# %%
dataFrame.corr()["price"].sort_values()
# Out:
# mileage      -0.537214
# mpg          -0.438445
# tax           0.268717
# engineSize    0.516126
# year          0.520712
# price         1.000000
# Name: price, dtype: float64

# %%
sbn.scatterplot(x="mileage" ,y="price",data=dataFrame)

# %%
dataFrame.sort_values("price", ascending =False).head(20 ) # en yüksek fiyatlı 20 arabayı getir
# Out:
#        year   price transmission  mileage  tax   mpg  engineSize
# 6199   2020  159999    Semi-Auto     1350  145  21.4         4.0
# 10044  2020  154998    Automatic     3000  150  21.4         4.0
# 5      2011  149948    Automatic     3000  570  21.4         6.2
# 8737   2019  140319    Semi-Auto      785  150  22.1         4.0
# 6386   2018  139995    Semi-Auto    13046  145  21.4         4.0
# 8      2019  139948    Automatic    12000  145  21.4         4.0
# 9133   2019  139559    Semi-Auto     1000  145  22.1         4.0
# 8821   2020  138439    Semi-Auto     1000  145  22.1         4.0
# 5902   2018  135771    Semi-Auto    19000  145  21.4         4.0
# 7864   2018  135124    Semi-Auto    18234  150  21.4         4.0
# 8673   2019  134219    Semi-Auto     1000  145  24.8         4.0
# 6210   2019  129990    Automatic     1000  145  24.8         4.0
# 4759   2019  126000    Automatic      250  145  24.6         4.0
# ...

# %%
dataFrame.sort_values("price", ascending =True).head(20 ) # fiyatı yükselen şekilde 20 arabayı getir
# Out:
#        year  price transmission  mileage  tax   mpg  engineSize
# 11816  2003    650       Manual   109090  235  40.0         1.4
# 12008  2010   1350       Manual   116126  145  54.3         2.0
# 11765  2000   1490    Automatic    87000  265  27.2         3.2
# 11549  2002   1495    Automatic    13800  305  39.8         2.7
# 12594  2004   1495       Manual   119000  300  34.5         1.8
# 11174  2001   1695    Automatic   108800  325  31.7         3.2
# 12710  2006   1695    Automatic   153000  300  33.6         1.8
# 12766  2004   1780    Automatic   118000  265  41.5         2.2
# 12009  2007   1800    Automatic    84000  200  42.8         1.5
# 11764  1998   1990    Automatic    99300  265  32.1         2.3
# 11808  1998   1990    Automatic   113557  265  32.1         2.3
# 11383  2005   1995    Automatic   105000  260  43.5         2.1
# 11378  2004   1995    Semi-Auto   165000  330  20.0         3.7
# 11857  2002   2140    Automatic    52700  325  31.4         2.0
# ...

# %%
len(dataFrame)
# Out:
# 13119

# %%
len(dataFrame)* 0.01 # en yüksek 131 arabayı çıkartırsam genel veri  setimi fazla etkilemez
# Out:
# 131.19

# %%
yuzdeDoksanDokuzDf =dataFrame.sort_values("price",ascending=False).iloc[131:] # en yüksek 131 den sonrasını ver

# %%
yuzdeDoksanDokuzDf.describe()
# Out:
#                year         price        mileage           tax           mpg  \
# count  12988.000000  12988.000000   12988.000000  12988.000000  12988.000000
# mean    2017.281876  24074.926933   22132.741146    129.689714     55.437142
# std        2.228515   9866.224575   21196.776401     65.183076     15.025999
# min     1970.000000    650.000000       1.000000      0.000000      1.100000
# 25%     2016.000000  17357.500000    6322.000000    125.000000     45.600000
# 50%     2018.000000  22299.000000   15369.500000    145.000000     56.500000
# 75%     2019.000000  28706.000000   31982.250000    145.000000     64.200000
# max     2020.000000  65990.000000  259000.000000    580.000000    217.300000
#
#          engineSize
# count  12988.000000
# mean       2.050901
# std        0.532596
# min        0.000000
# 25%        1.675000
# 50%        2.000000
# 75%        2.100000
# max        6.200000

# %%
plt.figure(figsize=(7,5))
sbn.distplot(yuzdeDoksanDokuzDf["price"])

# %%
dataFrame.groupby("year").mean()["price"] # yıılara göre ort araba fiyatları
# Out:
# year
# 1970    24999.000000
# 1997     9995.000000
# 1998     8605.000000
# 1999     5995.000000
# 2000     5743.333333
# 2001     4957.900000
# 2002     5820.444444
# 2003     4878.000000
# 2004     4727.615385
# 2005     4426.111111
# 2006     4036.875000
# 2007     5136.045455
# 2008     6967.437500
# 2009     6166.764706
# 2010     8308.473684
# 2011    12624.894737
# 2012    10845.140351
# 2013    11939.842466
# 2014    14042.936864
# 2015    16731.780020
# 2016    19307.892948
# 2017    21514.307854
# 2018    25720.162918
# 2019    31290.020865
# 2020    35433.282337
# Name: price, dtype: float64

# %%
dataFrame.groupby("year").mean()["price"] # yıılara göre ort araba fiyatları
# Out:
# year
# 1970    24999.000000
# 1997     9995.000000
# 1998     8605.000000
# 1999     5995.000000
# 2000     5743.333333
# 2001     4957.900000
# 2002     5820.444444
# 2003     4878.000000
# 2004     4727.615385
# 2005     4426.111111
# 2006     4036.875000
# 2007     5136.045455
# 2008     6967.437500
# 2009     6166.764706
# 2010     8308.473684
# 2011    12624.894737
# 2012    10845.140351
# 2013    11939.842466
# 2014    14042.936864
# 2015    16731.780020
# 2016    19307.892948
# 2017    21514.307854
# 2018    25720.162918
# 2019    31290.020865
# 2020    35433.282337
# Name: price, dtype: float64

# %%
dataFrame[dataFrame.year != 1970].groupby("year").mean()["price"]
# Out:
# year
# 1997     9995.000000
# 1998     8605.000000
# 1999     5995.000000
# 2000     5743.333333
# 2001     4957.900000
# 2002     5820.444444
# 2003     4878.000000
# 2004     4727.615385
# 2005     4426.111111
# 2006     4036.875000
# 2007     5136.045455
# 2008     6967.437500
# 2009     6166.764706
# 2010     8308.473684
# 2011    12624.894737
# 2012    10845.140351
# 2013    11939.842466
# 2014    14042.936864
# 2015    16731.780020
# 2016    19307.892948
# 2017    21514.307854
# 2018    25720.162918
# 2019    31290.020865
# 2020    35433.282337
# Name: price, dtype: float64

# %%
dataFrame= yuzdeDoksanDokuzDf

# %%
dataFrame
# Out:
#        year  price transmission  mileage  tax   mpg  engineSize
# 6177   2019  65990    Semi-Auto     5076  150  30.4         3.0
# 5779   2020  65990    Semi-Auto      999  145  28.0         4.0
# 3191   2020  65980    Semi-Auto     3999  145  28.0         4.0
# 4727   2019  65000    Semi-Auto     3398  145  27.2         4.0
# 8814   2019  64999    Semi-Auto      119  145  40.9         3.0
# 8083   2018  64999    Semi-Auto    41102  145  23.0         5.5
# 267    2019  64998    Semi-Auto      313  145  31.4         4.7
# 2956   2020  64980    Semi-Auto     3999  145  40.4         3.0
# 2274   2020  64980    Semi-Auto     3999  145  40.4         3.0
# 12160  2018  64950    Automatic    13000  145  28.5         3.0
# 8869   2020  64359    Semi-Auto     1000  145  29.5         3.0
# 6218   2019  63999    Automatic      618  145  52.3         3.0
# 9590   2018  63990    Automatic    28300  145  30.1         4.0
# 6032   2019  63495    Automatic      500  145  28.0         4.0
# ...

# %%
dataFrame = dataFrame[dataFrame.year!=1970]

# %%
dataFrame.groupby("year").mean()["price"]
# Out:
# year
# 1997     9995.000000
# 1998     8605.000000
# 1999     5995.000000
# 2000     5743.333333
# 2001     4957.900000
# 2002     5820.444444
# 2003     4878.000000
# 2004     4727.615385
# 2005     4426.111111
# 2006     4036.875000
# 2007     5136.045455
# 2008     6967.437500
# 2009     6166.764706
# 2010     8308.473684
# 2011     8913.459459
# 2012    10845.140351
# 2013    11939.842466
# 2014    14042.936864
# 2015    16647.822222
# 2016    19223.558943
# 2017    21356.280421
# 2018    24800.844506
# 2019    30289.524832
# 2020    34234.794872
# Name: price, dtype: float64

# %%
dataFrame.head()
# Out:
#       year  price transmission  mileage  tax   mpg  engineSize
# 6177  2019  65990    Semi-Auto     5076  150  30.4         3.0
# 5779  2020  65990    Semi-Auto      999  145  28.0         4.0
# 3191  2020  65980    Semi-Auto     3999  145  28.0         4.0
# 4727  2019  65000    Semi-Auto     3398  145  27.2         4.0
# 8814  2019  64999    Semi-Auto      119  145  40.9         3.0

# %%
dataFrame=dataFrame.drop("transmission",axis=1)

# %%
dataFrame.head()
# Out:
#       year  price  mileage  tax   mpg  engineSize
# 6177  2019  65990     5076  150  30.4         3.0
# 5779  2020  65990      999  145  28.0         4.0
# 3191  2020  65980     3999  145  28.0         4.0
# 4727  2019  65000     3398  145  27.2         4.0
# 8814  2019  64999      119  145  40.9         3.0

# %%
y=dataFrame["price"].values
x=dataFrame.drop("price",axis=1).values

# %%
x
# Out:
# array([[2.01900e+03, 5.07600e+03, 1.50000e+02, 3.04000e+01, 3.00000e+00],
#        [2.02000e+03, 9.99000e+02, 1.45000e+02, 2.80000e+01, 4.00000e+00],
#        [2.02000e+03, 3.99900e+03, 1.45000e+02, 2.80000e+01, 4.00000e+00],
#        ...,
#        [2.00000e+03, 8.70000e+04, 2.65000e+02, 2.72000e+01, 3.20000e+00],
#        [2.01000e+03, 1.16126e+05, 1.45000e+02, 5.43000e+01, 2.00000e+00],
#        [2.00300e+03, 1.09090e+05, 2.35000e+02, 4.00000e+01, 1.40000e+00]])

# %%
y
# Out:
# array([65990, 65990, 65980, ...,  1490,  1350,   650], dtype=int64)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3,random_state=10)

# %%
len(x_train)
# Out:
# 9090

# %%
len(x_test)
# Out:
# 3897

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)

# %%
from tensorflow.keras.models import Sequential #yapay sinir ağı kullan
from tensorflow.keras.layers import Dense #yapay sinir ağında katman oluştur
# Out:
# C:\Users\MONSTER\anaconda3\envs\py35\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
x_train.shape
# Out:
# (9090, 5)

# %%
model= Sequential()
model.add(Dense(12,activation="relu"))
model.add(Dense(12,activation="relu"))
model.add(Dense(12,activation="relu"))
model.add(Dense(12,activation="relu"))

model.add(Dense(1))

model.compile(optimizer="adam",loss="mse")

# %%
model.fit(x=x_train, y = y_train, validation_data=(x_test,y_test),epochs=300)
#,batch_size=240  ,validation_data=(x_test,y_test)
#validation data  = doğrulama verisini direk model içinde verdim
#batch_size=250  verim büyük ve bu  yapımı yorar o yüzden parca parca veriyorum
# Out:
# Train on 9090 samples, validate on 3897 samples
# Epoch 1/300
# 9090/9090 [==============================] - 6s 630us/step - loss: 661230332.2684 - val_loss: 615844429.7131
# Epoch 2/300
# 9090/9090 [==============================] - 2s 188us/step - loss: 284571476.6293 - val_loss: 69088761.6649
# Epoch 3/300
# 9090/9090 [==============================] - 1s 160us/step - loss: 50505690.3265 - val_loss: 43646482.7180
# Epoch 4/300
# 9090/9090 [==============================] - 1s 146us/step - loss: 37554858.6389 - val_loss: 35166803.6664
# Epoch 5/300
# 9090/9090 [==============================] - 1s 147us/step - loss: 31244395.1683 - val_loss: 30288127.5514
# Epoch 6/300
# 9090/9090 [==============================] - 1s 148us/step - loss: 27286659.7604 - val_loss: 26943257.7614
# Epoch 7/300
# 7168/9090 [======================>.......] - ETA: 0s - loss: 24749493.1116
